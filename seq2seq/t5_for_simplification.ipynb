# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Installing requiremnts

# %%
# !pip install --upgrade setuptools
# !pip install ez_setup
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (67.7.2)
# Collecting setuptools
#   Downloading setuptools-67.8.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 40.7 MB/s eta 0:00:00
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.7.2
#     Uninstalling setuptools-67.7.2:
#       Successfully uninstalled setuptools-67.7.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# Successfully installed setuptools-67.8.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ez_setup
#   Downloading ez_setup-0.9.tar.gz (6.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ez_setup
#   Building wheel for ez_setup (setup.py) ... done
#   Created wheel for ez_setup: filename=ez_setup-0.9-py3-none-any.whl size=10997 sha256=ad3bb0db66f8c5da608aee5adf98e49f7a4a370b5cada2b38ffe5de4ef0948bb
#   Stored in directory: /root/.cache/pip/wheels/7a/d6/77/8f495e85fb7df23d41c328b9ea3cf0d9e83631b20bba479293
# Successfully built ez_setup
# Installing collected packages: ez_setup
# Successfully installed ez_setup-0.9

# %%
# !git clone https://github.com/feralvam/easse
# !git clone https://github.com/Andoree/sent_simplification.git
# !cp sent_simplification/sari.py /content/easse/easse
# Out:
# Cloning into 'easse'...
# remote: Enumerating objects: 1960, done.
# remote: Counting objects: 100% (133/133), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 1960 (delta 107), reused 95 (delta 95), pack-reused 1827
# Receiving objects: 100% (1960/1960), 33.14 MiB | 19.42 MiB/s, done.
# Resolving deltas: 100% (1229/1229), done.
# Cloning into 'sent_simplification'...
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 37 (delta 18), reused 8 (delta 2), pack-reused 0
# Unpacking objects: 100% (37/37), 10.78 KiB | 1003.00 KiB/s, done.

# %%
# %cd /content/easse
# !pip install .
# %cd /content/
# Out:
# /content/easse
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/easse
#   Preparing metadata (setup.py) ... done
# Collecting tseval@ git+https://github.com/facebookresearch/text-simplification-evaluation.git@main (from easse==0.2.4)
#   Cloning https://github.com/facebookresearch/text-simplification-evaluation.git (to revision main) to /tmp/pip-install-255kzp9u/tseval_c4379cb4f9af487fb1a66ae246bd50d0
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/text-simplification-evaluation.git /tmp/pip-install-255kzp9u/tseval_c4379cb4f9af487fb1a66ae246bd50d0
#   Resolved https://github.com/facebookresearch/text-simplification-evaluation.git to commit f335e2e27026321c7c3d1dd63857416c7e7397b2
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from easse==0.2.4) (8.1.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from easse==0.2.4) (3.7.1)
# Requirement already satisfied: nltk>=3.6.5 in /usr/local/lib/python3.10/dist-packages (from easse==0.2.4) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from easse==0.2.4) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from easse==0.2.4) (1.5.3)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from easse==0.2.4) (2.27.1)
# Collecting sacrebleu>=2.0.0 (from easse==0.2.4)
#   Downloading sacrebleu-2.3.1-py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 8.4 MB/s eta 0:00:00
# Collecting sacremoses (from easse==0.2.4)
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 45.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from easse==0.2.4) (0.12.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from easse==0.2.4) (1.2.2)
# Collecting stanfordnlp (from easse==0.2.4)
#   Downloading stanfordnlp-0.2.0-py3-none-any.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 22.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.32.2 in /usr/local/lib/python3.10/dist-packages (from easse==0.2.4) (4.65.0)
# Collecting yattag (from easse==0.2.4)
#   Downloading yattag-1.15.1.tar.gz (28 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: plotly>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from easse==0.2.4) (5.13.1)
# Collecting bert_score (from easse==0.2.4)
#   Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 8.9 MB/s eta 0:00:00
# Collecting simalign (from easse==0.2.4)
#   Downloading simalign-0.3-py3-none-any.whl (8.1 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.6.5->easse==0.2.4) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.6.5->easse==0.2.4) (2022.10.31)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.0.0->easse==0.2.4) (8.2.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->easse==0.2.4) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->easse==0.2.4) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->easse==0.2.4) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->easse==0.2.4) (3.4)
# Collecting portalocker (from sacrebleu>=2.0.0->easse==0.2.4)
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=2.0.0->easse==0.2.4) (0.8.10)
# Collecting colorama (from sacrebleu>=2.0.0->easse==0.2.4)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=2.0.0->easse==0.2.4) (4.9.2)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score->easse==0.2.4) (2.0.1+cu118)
# Collecting transformers>=3.0.0 (from bert_score->easse==0.2.4)
#   Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 44.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert_score->easse==0.2.4) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->easse==0.2.4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->easse==0.2.4) (2022.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->easse==0.2.4) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->easse==0.2.4) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->easse==0.2.4) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->easse==0.2.4) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->easse==0.2.4) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->easse==0.2.4) (3.0.9)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from sacremoses->easse==0.2.4) (1.16.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->easse==0.2.4) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->easse==0.2.4) (3.1.0)
# Collecting networkx==2.4 (from simalign->easse==0.2.4)
#   Downloading networkx-2.4-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 71.8 MB/s eta 0:00:00
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from networkx==2.4->simalign->easse==0.2.4) (4.4.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from stanfordnlp->easse==0.2.4) (3.20.3)
# Collecting sklearn (from tseval@ git+https://github.com/facebookresearch/text-simplification-evaluation.git@main->easse==0.2.4)
#   Downloading sklearn-0.0.post5.tar.gz (3.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting python-Levenshtein (from tseval@ git+https://github.com/facebookresearch/text-simplification-evaluation.git@main->easse==0.2.4)
#   Downloading python_Levenshtein-0.21.0-py3-none-any.whl (9.4 kB)
# Collecting gitpython (from tseval@ git+https://github.com/facebookresearch/text-simplification-evaluation.git@main->easse==0.2.4)
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 21.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score->easse==0.2.4) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score->easse==0.2.4) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score->easse==0.2.4) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score->easse==0.2.4) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score->easse==0.2.4) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.0.0->bert_score->easse==0.2.4) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.0.0->bert_score->easse==0.2.4) (16.0.5)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers>=3.0.0->bert_score->easse==0.2.4)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 23.4 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score->easse==0.2.4) (6.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers>=3.0.0->bert_score->easse==0.2.4)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 41.0 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1 (from gitpython->tseval@ git+https://github.com/facebookresearch/text-simplification-evaluation.git@main->easse==0.2.4)
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.4 MB/s eta 0:00:00
# Collecting Levenshtein==0.21.0 (from python-Levenshtein->tseval@ git+https://github.com/facebookresearch/text-simplification-evaluation.git@main->easse==0.2.4)
#   Downloading Levenshtein-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.1/174.1 kB 25.6 MB/s eta 0:00:00
# Collecting rapidfuzz<4.0.0,>=2.3.0 (from Levenshtein==0.21.0->python-Levenshtein->tseval@ git+https://github.com/facebookresearch/text-simplification-evaluation.git@main->easse==0.2.4)
#   Downloading rapidfuzz-3.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 115.2 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython->tseval@ git+https://github.com/facebookresearch/text-simplification-evaluation.git@main->easse==0.2.4)
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers>=3.0.0->bert_score->easse==0.2.4) (2023.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert_score->easse==0.2.4) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.0.0->bert_score->easse==0.2.4) (1.3.0)
# Building wheels for collected packages: easse, sacremoses, tseval, yattag, sklearn
#   Building wheel for easse (setup.py) ... done
#   Created wheel for easse: filename=easse-0.2.4-py3-none-any.whl size=5318484 sha256=8ba4146dba7910d51f858439b4af101935fcae337b17b3f3fc46759a8f833050
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dfpkr8t2/wheels/a7/c7/f7/b94a747d4c5740f01e294a94eaaaf173f0d2666a35505170d7
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895241 sha256=448da514bec360f504c4ae3f7d69fd1f5ec08f24c631b8c7eb0b18e883013903
#   Stored in directory: /root/.cache/pip/wheels/00/24/97/a2ea5324f36bc626e1ea0267f33db6aa80d157ee977e9e42fb
#   Building wheel for tseval (setup.py) ... done
#   Created wheel for tseval: filename=tseval-1.0-py3-none-any.whl size=8522216 sha256=c05f4c6d32594a5929fb8f698182d306c22f9b17809b05762263c1fed971b6ed
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dfpkr8t2/wheels/89/be/e9/c9b30865c44c542db11cefa3afb9fb31d1f7136f5093d2e0b4
#   Building wheel for yattag (setup.py) ... done
#   Created wheel for yattag: filename=yattag-1.15.1-py3-none-any.whl size=15630 sha256=9cc238f57c54152534e33f1696c6507e93e350258ffa43f24b423d059ff8728d
#   Stored in directory: /root/.cache/pip/wheels/c0/f7/67/89165fb6c0e73ad142c1a60daed9e773af08961396d06fa391
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post5-py3-none-any.whl size=2950 sha256=827d5424b64e816267b51149e24aa9b175db9a85a74212d4286b3394d01ce1a9
#   Stored in directory: /root/.cache/pip/wheels/38/1f/8d/4f812c590e074c1e928f5cec67bf5053b71f38e2648739403a
# Successfully built easse sacremoses tseval yattag sklearn
# Installing collected packages: yattag, tokenizers, sklearn, smmap, sacremoses, rapidfuzz, portalocker, networkx, colorama, sacrebleu, Levenshtein, huggingface-hub, gitdb, transformers, python-Levenshtein, gitpython, tseval, stanfordnlp, simalign, bert_score, easse
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.1
#     Uninstalling networkx-3.1:
#       Successfully uninstalled networkx-3.1
# Successfully installed Levenshtein-0.21.0 bert_score-0.3.13 colorama-0.4.6 easse-0.2.4 gitdb-4.0.10 gitpython-3.1.31 huggingface-hub-0.14.1 networkx-2.4 portalocker-2.7.0 python-Levenshtein-0.21.0 rapidfuzz-3.0.0 sacrebleu-2.3.1 sacremoses-0.0.53 simalign-0.3 sklearn-0.0.post5 smmap-5.0.0 stanfordnlp-0.2.0 tokenizers-0.13.3 transformers-4.29.2 tseval-1.0 yattag-1.15.1
# /content

# %%
# !git clone https://github.com/anna-marshalova/text_simplifier
# Out:
# Cloning into 'text_simplifier'...
# remote: Enumerating objects: 101, done.
# remote: Counting objects: 100% (101/101), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 101 (delta 41), reused 86 (delta 26), pack-reused 0
# Receiving objects: 100% (101/101), 1.20 MiB | 20.87 MiB/s, done.
# Resolving deltas: 100% (41/41), done.

# %%
# !pip install -r text_simplifier/experiments/requirements.txt
# !pip install -r text_simplifier/seq2seq/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/Koziev/rusyllab (from -r text_simplifier/experiments/requirements.txt (line 4))
#   Cloning https://github.com/Koziev/rusyllab to /tmp/pip-req-build-auaatn5n
#   Running command git clone --filter=blob:none --quiet https://github.com/Koziev/rusyllab /tmp/pip-req-build-auaatn5n
#   Resolved https://github.com/Koziev/rusyllab to commit c5d0ea405e9cc8233bd65503c26c0d2ad8b5cb57
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Levenshtein in /usr/local/lib/python3.10/dist-packages (from -r text_simplifier/experiments/requirements.txt (line 1)) (0.21.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from -r text_simplifier/experiments/requirements.txt (line 2)) (3.8.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from -r text_simplifier/experiments/requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: rapidfuzz<4.0.0,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from Levenshtein->-r text_simplifier/experiments/requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->-r text_simplifier/experiments/requirements.txt (line 2)) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->-r text_simplifier/experiments/requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->-r text_simplifier/experiments/requirements.txt (line 2)) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->-r text_simplifier/experiments/requirements.txt (line 2)) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r text_simplifier/experiments/requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r text_simplifier/experiments/requirements.txt (line 3)) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->-r text_simplifier/experiments/requirements.txt (line 3)) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->-r text_simplifier/experiments/requirements.txt (line 3)) (1.16.0)
# Building wheels for collected packages: rusyllab
#   Building wheel for rusyllab (setup.py) ... done
#   Created wheel for rusyllab: filename=rusyllab-0.0.4-py3-none-any.whl size=16015 sha256=fdc846a813c1816786d2417d2191e0d6ccdad1b6172d0702684f48af67947a18
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2wajrw9i/wheels/d6/3d/e5/02d3ad4c9dcbd52cfcf19fe3373c7c2edc996e8ae4257292cf
# Successfully built rusyllab
# Installing collected packages: rusyllab
# Successfully installed rusyllab-0.0.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r text_simplifier/seq2seq/requirements.txt (line 1)) (1.22.4)
# Collecting sentencepiece==0.1.99 (from -r text_simplifier/seq2seq/requirements.txt (line 2))
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 23.4 MB/s eta 0:00:00
# Requirement already satisfied: torch==2.0.1 in /usr/local/lib/python3.10/dist-packages (from -r text_simplifier/seq2seq/requirements.txt (line 3)) (2.0.1+cu118)
# Collecting transformers==4.27 (from -r text_simplifier/seq2seq/requirements.txt (line 4))
#   Downloading transformers-4.27.0-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 47.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->-r text_simplifier/seq2seq/requirements.txt (line 3)) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->-r text_simplifier/seq2seq/requirements.txt (line 3)) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->-r text_simplifier/seq2seq/requirements.txt (line 3)) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->-r text_simplifier/seq2seq/requirements.txt (line 3)) (2.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->-r text_simplifier/seq2seq/requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->-r text_simplifier/seq2seq/requirements.txt (line 3)) (2.0.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27->-r text_simplifier/seq2seq/requirements.txt (line 4)) (0.14.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27->-r text_simplifier/seq2seq/requirements.txt (line 4)) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27->-r text_simplifier/seq2seq/requirements.txt (line 4)) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27->-r text_simplifier/seq2seq/requirements.txt (line 4)) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.27->-r text_simplifier/seq2seq/requirements.txt (line 4)) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27->-r text_simplifier/seq2seq/requirements.txt (line 4)) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27->-r text_simplifier/seq2seq/requirements.txt (line 4)) (4.65.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->-r text_simplifier/seq2seq/requirements.txt (line 3)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->-r text_simplifier/seq2seq/requirements.txt (line 3)) (16.0.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.27->-r text_simplifier/seq2seq/requirements.txt (line 4)) (2023.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.0.1->-r text_simplifier/seq2seq/requirements.txt (line 3)) (2.1.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from networkx->torch==2.0.1->-r text_simplifier/seq2seq/requirements.txt (line 3)) (4.4.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.27->-r text_simplifier/seq2seq/requirements.txt (line 4)) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.27->-r text_simplifier/seq2seq/requirements.txt (line 4)) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.27->-r text_simplifier/seq2seq/requirements.txt (line 4)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.27->-r text_simplifier/seq2seq/requirements.txt (line 4)) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.1->-r text_simplifier/seq2seq/requirements.txt (line 3)) (1.3.0)
# Installing collected packages: sentencepiece, transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.29.2
#     Uninstalling transformers-4.29.2:
#       Successfully uninstalled transformers-4.29.2
# Successfully installed sentencepiece-0.1.99 transformers-4.27.0

# %% [markdown]
# #Loading data

# %%
# !git clone https://github.com/dialogue-evaluation/RuSimpleSentEval
# !git clone https://github.com/Digital-Pushkin-Lab/RuAdapt
# Out:
# Cloning into 'RuSimpleSentEval'...
# remote: Enumerating objects: 110, done.
# remote: Counting objects: 100% (110/110), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 110 (delta 38), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (110/110), 608.89 KiB | 2.39 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# Cloning into 'RuAdapt'...
# remote: Enumerating objects: 83, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 83 (delta 47), reused 75 (delta 42), pack-reused 0
# Unpacking objects: 100% (83/83), 4.15 MiB | 3.23 MiB/s, done.

# %%
# %cd text_simplifier
# Out:
# /content/text_simplifier

# %%
import pandas as pd
from experiments.data import SOURCE_COLUMN_NAME, TARGET_COLUMN_NAME, filter_ru_adapt, info
from experiments.paths import RU_ADAPT_PATHS, RUSIMPLESENTEVAL_PATH, TEST_DATA_PATH
senteval = pd.read_csv(RUSIMPLESENTEVAL_PATH)
ru_adapt_dfs = []
ru_adapt_dfs.append(filter_ru_adapt(RU_ADAPT_PATHS[0], min_sim = 0.75, min_lev = 20, max_elong_rate = 0.1))
for path in RU_ADAPT_PATHS[1:]:
  ru_adapt_dfs.append(filter_ru_adapt(path, min_sim = 0.5, min_lev = 5, max_elong_rate = 0.1))
info([RUSIMPLESENTEVAL_PATH] + RU_ADAPT_PATHS, [senteval] + ru_adapt_dfs)
# Out:
# Name: dev_sents.csv  Size: 3406
# Name: zlatoust_sentence_aligned_with_CATS.csv  Size: 923
# Name: lsslovar_B_to_A_sent.csv  Size: 294
# Name: lsslovar_C_to_A_sent.csv  Size: 286
# Name: lsslovar_C_to_B_sent.csv  Size: 1202
# Name: df_fairytales_sent.csv  Size: 65

# %%
data = pd.concat([senteval]+ru_adapt_dfs)[[SOURCE_COLUMN_NAME, TARGET_COLUMN_NAME]]
data.head()
# Out:
#                                         INPUT:source  \
# 0  14 декабря 1944 года рабочий посёлок Ички был ...
# 1   1960 году была выпущена модель 172A. Изменени...
# 2   1960 году была выпущена модель 172A. Изменени...
# 3   1960 году была выпущена модель 172A. Изменени...
# 4   1960 году была выпущена модель 172A. Изменени...
#
#                                        OUTPUT:output
# 0  14 декабря 1944 года рабочий посёлок Ички пере...
# 1  В 1960 году вышла модель 172А. Отличие в хвост...
# 2  В выпущенной в 1960 году модель имела изменени...
# 3  Изменения: в хвосте и руле направления с обрат...
# 4  Модель 172А с другим хвостовым оперением,  кре...

# %%
test_data = pd.read_csv(TEST_DATA_PATH)
info([TEST_DATA_PATH], [test_data])
# Out:
# Name: public_test_sents.csv  Size: 3398

# %%
from experiments.data import prepare_data_for_eval
orig, refs = prepare_data_for_eval(data)
print(f'Unique train sents: {len(orig)}')
test_orig, test_refs = prepare_data_for_eval(test_data)
print(f'Unique test sents: {len(test_orig)}')
# Out:
#   0%|          | 0/3454 [00:00<?, ?it/s]
# Unique train sents: 3454
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Unique test sents: 1000

# %% [markdown]
# #Training

# %%
# %cd text_simplifier
# Out:
# [Errno 2] No such file or directory: 'text_simplifier'
# /content/text_simplifier

# %%
from seq2seq.paths import get_checkpoints_path
from seq2seq.model import get_model, get_tokenizer
MODEL_ID = 'rut5-base'
DATASET = 'senteval+ruadapt'
checkpoints_path = get_checkpoints_path(MODEL_ID, DATASET)
model = get_model(MODEL_ID, checkpoints_path = checkpoints_path)
tokenizer = get_tokenizer(MODEL_ID)
# Out:
# Loading pretrained model sberbank-ai/ruT5-base
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]
# Downloading spiece.model:   0%|          | 0.00/1.00M [00:00<?, ?B/s]

# %%
from seq2seq.utils import sent_length_info
sent_length_info(data[SOURCE_COLUMN_NAME], tokenizer)
# Out:
# Average text length: 32.284650259067355
# Median text length: 29.0
# Max text length: 243

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader
from seq2seq.utils import RANDOM_STATE, BATCH_SIZE
from seq2seq.dataset import Dataset
print(f'Batch size is {BATCH_SIZE}')
train_data, val_data = train_test_split(data, test_size=0.2, random_state = RANDOM_STATE)
train_dataset = Dataset(train_data, tokenizer, max_length = 50)
print(f'Train data: {len(train_dataset)} sentences')
val_dataset = Dataset(val_data, tokenizer, max_length = 50)
print(f'Val data: {len(val_dataset)} sentences')
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
# Out:
# Batch size is 32
# Train data: 4940 sentences
# Val data: 1236 sentences

# %%
from experiments.utils import set_logging
logger = set_logging()
# %cd text_simplifier
# Out:
# [Errno 2] No such file or directory: 'text_simplifier'
# /content/text_simplifier

# %%
from seq2seq.trainer import train
train(model, tokenizer,
      train_loader, val_loader, 
      model_id = MODEL_ID, dataset_name = DATASET, 
      checkpoints_path = checkpoints_path, 
      logger = logger, 
      orig = orig, refs = refs, 
      max_epochs = 20, 
      cleanup_step = 1, report_epoch = 5, save_epoch = 5)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/155 [00:00<?, ?it/s]
# Epoch 1, step 154: train loss: 2.5137  val loss: 6.4174
# SOURCE: С нежностью и заботой относится только к сыну Митрофанушке, недорослю (то есть молодому человеку, не достигшему совершеннолетия и не поступившему на службу), который растет избалованным, грубым, невежественным бездельником.
# TARGET: С нежностью и заботой относится только к сыну Митрофанушке.
# PREDICTION: С Любовью и заботой относится к сыну Митрофанушке (то есть молодому человеку, не достигшему совершеннолетия и не поступившему на службу, который растет избалованным, невежественным, невежественным бездельником, то есть к сыну Митрофанушке, который растет бездельником, который растет из-за него.
#   0%|          | 0/155 [00:00<?, ?it/s]
# Epoch 2, step 154: train loss: 1.8869  val loss: 6.8073
# SOURCE: После Крещения Руси из Византии пришли новые виды монументальной живописи — мозаика и фреска, а также станковая живопись (иконопись).
# TARGET: Мозаика, фреска, станковая живопись появились на Руси из-за влияния Византии.
# PREDICTION: После Крещения Руси из Византии пришли новые виды монументальной живописи — мозаика и фреска, а также станковая живопись, а также иконопись.
#   0%|          | 0/155 [00:00<?, ?it/s]
# Epoch 3, step 154: train loss: 1.7280  val loss: 6.7872
# SOURCE: Встречаются даже странные случаи: из-за желания оригинальности иной честный человек готов решиться даже на низкое дело; бывает даже и так, что, иной из этих несчастных не только честен, но даже и добр, провидение своего семейства, содержит и питает своими трудами даже чужих, не только своих, и что же?
# TARGET: Встречаются среди него даже странные случаи: из-за желания оригинальности иной честный человек готов решиться даже на низкое дело; бывает даже и так, что иной из этих несчастных не только честен, но даже и добр, надежда своей семьи, помогает своим трудом даже чужим, не только своим, и что же?
# PREDICTION: Из-за желания оригинальности иной честный человек готов решиться даже на низкое дело, а иной из этих несчастных не только честен, но даже и рад, что, может быть, даже чужой, но даже и не только чужой, не только честен, но и рад, и что же же.
#   0%|          | 0/155 [00:00<?, ?it/s]
# Epoch 4, step 154: train loss: 1.6128  val loss: 6.8718
# SOURCE: Русь еще в своем восточнославянском единстве, до татаро-монгольского ига, когда она не выделила из себя три основных восточнославянских парода — украинцев, великорусов и белорусов, — знала уже мужество непротивления.
# TARGET: Русь ещё до татаро-монгольского ига, когда она не выделила из себя украинцев, великорусов и белорусов, знала уже мужество непротивления.
# PREDICTION: Русь еще в своем восточнославянском единстве до татаро-монгольского ига, когда она не выделила из себя три главных восточнославянских парода — украинцев, белорусов и белорусов, знала уже мужество непротивления.
#   0%|          | 0/155 [00:00<?, ?it/s]
# Epoch 5, step 154: train loss: 1.5348  val loss: 6.8988
# SOURCE: Была влюблена в одного журналиста, в трех славян, в Комисарова; в одного министра, одного доктора, одного английского миссионера и в Каренина.
# TARGET: Была влюблена в одного журналиста, одного министра, одного доктора, одного английского миссионера и в Каренина.
# PREDICTION: Влюбленилась в одного журналиста, в Комисарова; в одного русского, в одного министра, одного английского, в одного министра, одного министра, одного английского миссионера и в Каренина.
# Model saved to content/drive/MyDrive/simplicity/checkpoints/rut5-base-senteval+ruadapt.pt
# Computing sari and bleu
#   0%|          | 0/108 [00:00<?, ?it/s]
# INFO:results: model:rut5-base dataset: senteval+ruadapt bleu:36.858 sari:1.896 fkgl:29.846 time:Fri May 26 17:44:33 2023
#   0%|          | 0/155 [00:00<?, ?it/s]
# Epoch 6, step 154: train loss: 1.4615  val loss: 7.0880
# SOURCE: Я принадлежу и всегда буду принадлежать только самой себе, но у меня есть жених, — строго сказала нахалу Варя
# TARGET: Варя строго сказала: — Я принадлежу и всегда буду принадлежать только самой себе.
# PREDICTION: Я принадлежу и всегда буду принадлежать только самой себе, но у меня есть жених, — строго сказала Варя. — У меня есть жених.
#   0%|          | 0/155 [00:00<?, ?it/s]
# Epoch 7, step 154: train loss: 1.3901  val loss: 6.9943
# SOURCE: Процедура начинается с того, что сотрудник ЗАГСа произносит торжественную речь о значении этого дня в жизни человека, затем спрашивает невесту и жениха, согласен ли каждый из них стать супругом.
# TARGET: Сотрудник ЗАГСа спрашивает невесту и жениха о согласии стать супругами.
# PREDICTION: Сначала спрашивает невесту и жениха, согласны ли они стать супругами.
#   0%|          | 0/155 [00:00<?, ?it/s]
# Epoch 8, step 154: train loss: 1.3386  val loss: 7.0761
# SOURCE: Васнецова к русским народным сказкам.
# TARGET: Васнецов.
# PREDICTION: Васнецова к русским народным сказкам.
#   0%|          | 0/155 [00:00<?, ?it/s]
# Epoch 9, step 154: train loss: 1.2878  val loss: 7.0191
# SOURCE: Нарисуйте эшафот так, чтобы видна была ясно и близко одна только последняя ступень; преступник ступил на нее: голова, лицо бледное как бумага, священник протягивает крест, тот с жадностию протягивает свои синие губы и глядит, и - все знает.
# TARGET: Нарисуйте так, чтобы видна была одна только последняя ступень лесенки; преступник встал на неё: голова, лицо бледное как бумага, священник протягивает крест, тот с жадностью протягивает свои синие губы и глядит, и — всё знает.
# PREDICTION: Нарисуйте эшафот так, чтобы голова, лицо бледное как бумага, священник протягивает крест, и смотрит, и
#   0%|          | 0/155 [00:00<?, ?it/s]
# Epoch 10, step 154: train loss: 1.2361  val loss: 7.1159
# SOURCE: В 2016 г. в Русской православной церкви насчитывается около 35 000 храмов, большая часть которых построена или восстановлена за последние 25 лет.
# TARGET: В 2016 г. в Русской православной церкви насчитывается около 35 000 храмов.
# PREDICTION: В 2016 г. в Русской православной церкви насчитывается около 35 000 храмов, большая часть из которых построена или восстановлена за последние 25 лет.
# Model saved to content/drive/MyDrive/simplicity/checkpoints/rut5-base-senteval+ruadapt.pt
# Computing sari and bleu
#   0%|          | 0/108 [00:00<?, ?it/s]
# INFO:results: model:rut5-base dataset: senteval+ruadapt bleu:60.526 sari:23.712 fkgl:29.443 time:Fri May 26 18:00:02 2023
#   0%|          | 0/155 [00:00<?, ?it/s]
# Epoch 11, step 154: train loss: 1.1810  val loss: 7.1324
# SOURCE: Скульптура создавалась и развивалась, чтобы представить древнеегипетских богов, фараонов, царей и цариц в физической форме.
# TARGET: Скульптура Египта развивалась, чтобы изображать древних богов и фараонов в физической форме.
# PREDICTION: Скульптура создавалась для того, чтобы показать древнеегипетских богов, фараонов, царей и цариц в физической форме.
#   0%|          | 0/155 [00:00<?, ?it/s]
# Epoch 12, step 154: train loss: 1.1466  val loss: 7.1286
# SOURCE: Первые два дня после отъезда жены Алексей Александрович принимал просителей, правителя дел, ездил в комитет и выходил обедать в столовую, как и обыкновенно.
# TARGET: Первые два дня после отъезда жены Алексей Александрович принимал просителей, ездил в комитет и выходил обедать в столовую, как обычно.
# PREDICTION: Первые два дня после отъезда жены Алексей Александрович ездил в комитет и выходил обедать обедать.
#   0%|          | 0/155 [00:00<?, ?it/s]
# Epoch 13, step 154: train loss: 1.0935  val loss: 7.2248
# SOURCE: Наконец, само расположение здания школы в центре Беслана создавало дополнительный риск провала диверсионной группы во время приближения к объекту.
# TARGET: Дополнительный риск провала диверсионной группы во время приближения к объекту стало само расположение здания школы в центре Беслана.
# PREDICTION: В это время здание школы в центре Беслана было школьным объектом, что создавало риск провала диверсионной группы во время приближения к объекту.
#   0%|          | 0/155 [00:00<?, ?it/s]
# Epoch 14, step 154: train loss: 1.0602  val loss: 7.3044
# SOURCE: Мы свиделись и проговорили целый час о делах, собственно одной Аглаи Ивановны касающихся; вот и все
# TARGET: Мы проговорили о делах, одной Аглаи Ивановны касающихся; вот и всё
# PREDICTION: Мы свиделись и проговорили целый час о делах, собственно одной Аглаи Ивановны касающихся.
#   0%|          | 0/155 [00:00<?, ?it/s]
# Epoch 15, step 154: train loss: 1.0214  val loss: 7.2587
# SOURCE: Это был Васенька Весловский, троюродный брат Щербацких, – петербургско-московский блестящий молодой человек, «отличнейший малый и страстный охотник», как его представил Степан Аркадьич.
# TARGET: Это был Васенька Весловский, троюродный брат Щербацких, — петербургскомос ковский молодой человек, «отличнейший человек и прекрасный охотник», как его представил Степан Аркадьич.
# PREDICTION: Он был петербургско-московский блестящий молодой человек, «отличнейший малый и страстный охотник», как его представил Степан Аркадьич.
# Model saved to content/drive/MyDrive/simplicity/checkpoints/rut5-base-senteval+ruadapt.pt
# Computing sari and bleu
#   0%|          | 0/108 [00:00<?, ?it/s]
# INFO:results: model:rut5-base dataset: senteval+ruadapt bleu:68.659 sari:27.53 fkgl:30.032 time:Fri May 26 18:16:17 2023
#   0%|          | 0/155 [00:00<?, ?it/s]
# Epoch 16, step 154: train loss: 0.9671  val loss: 7.4405
# SOURCE: На юге азербайджанская армия взяла под полный контроль территорию, прилегающую к границе с Ираном, а также город Шуша.
# TARGET: На юге азербайджанская армия взяла под контроль территорию рядом с  границей Ирана и город Шуша.
# PREDICTION: На юге азербайджанская армия захватила территорию, прилегающую к границе с Ираном и город Шуша.
#   0%|          | 0/155 [00:00<?, ?it/s]
# Epoch 17, step 154: train loss: 0.9438  val loss: 7.4438
# SOURCE: Многие лирические стихотворения поэта положены на музыку и стали романсами.
# TARGET: Многие лирические стихотворения поэта стали романсами,
# PREDICTION: Многие лирические стихи поэта стали романсами.
#   0%|          | 0/155 [00:00<?, ?it/s]
# Epoch 18, step 154: train loss: 0.9098  val loss: 7.4641
# SOURCE: Теперь он испытывал чувство, подобное тому, какое испытал бы человек, спокойно прошедший над пропастью по мосту и вдруг увидавший, что этот мост разобран и что там пучина.
# TARGET: Теперь он испытывал такое чувство, какое испытал бы человек, спокойно прошедший над пропастью по мосту и вдруг увидевший, что этот мост разобран и что внизу пропасть.
# PREDICTION: Теперь он испытывал чувство, подобное тому, какое испытал бы человек, спокойно прошедший над пропастью по мосту и вдруг увидавший, что этот мост разобран и что там пучина.
#   0%|          | 0/155 [00:00<?, ?it/s]
# Epoch 19, step 154: train loss: 0.8680  val loss: 7.6258
# SOURCE: Острова, образующие Новую Зеландию, располагаются в тихоокеанском геосинклинальном поясе между двумя литосферными плитами — тихоокеанской и австралийской.
# TARGET: Острова, образующие Новую Зеландию расположены между тихоокеанской и австралийской литосферными плитами.
# PREDICTION: Острова, образующие Новую Зеландию, находятся между двумя литосферными плитами — тихоокеанской и австралийской.
#   0%|          | 0/155 [00:00<?, ?it/s]
# Epoch 20, step 154: train loss: 0.8322  val loss: 7.6463
# SOURCE: План был оригинален и бедность парижских предместий ужасающей, но санкюлоты, деморализованные и запуганные после прериаля, не откликнулись на призывы бабувистов.
# TARGET: Запуганные санкюлоты после прериаля не откликались на призывы бабувистов, хотя план был оригинален
# PREDICTION: План был оригинален, санклюты, деморализованные и напуганные после прериаля, не откликались на призывы бабувистов.
# Model saved to content/drive/MyDrive/simplicity/checkpoints/rut5-base-senteval+ruadapt.pt
# Computing sari and bleu
#   0%|          | 0/108 [00:00<?, ?it/s]
# INFO:results: model:rut5-base dataset: senteval+ruadapt bleu:100.0 sari:28.699 fkgl:30.16 time:Fri May 26 18:33:28 2023

# %%
text = '14 декабря 1944 года рабочий посёлок Ички был переименован в рабочий посёлок Советский, после чего поселковый совет стал называться Советским.'
input_ids, attention_mask = tokenizer(text, return_tensors = 'pt').values()
input_ids.shape(1)

# %%
from experiments.utils import reload
reload('seq2seq.inference')
reload('seq2seq.trainer')
